# %%
# %load_ext autoreload
# %autoreload 2

# %%
from data import *

# %%
data = PWFDF_Data()

bounds = data.bounds(0, 5)
print(bounds)

output_file = '/home/quinn/pwfdf/data/dem.tif'
elevation.clip(bounds=bounds, output=output_file, product='SRTM1')
    
x, y = data.coordinates_wgs84(0)
print(f"x: {x}, y: {y}")
plot_dem(output_file, x, y)


delineate_watershed(output_file, (x, y))
# Out:
# (-118.4907467773275, 34.49662891577207, -118.3833471290849, 34.58806402907864)
# make: Entering directory '/home/quinn/.cache/elevation/SRTM1'
# make: Nothing to be done for 'download'.
# make: Leaving directory '/home/quinn/.cache/elevation/SRTM1'
# make: Entering directory '/home/quinn/.cache/elevation/SRTM1'
# make: Nothing to be done for 'all'.
# make: Leaving directory '/home/quinn/.cache/elevation/SRTM1'
# make: Entering directory '/home/quinn/.cache/elevation/SRTM1'
# cp SRTM1.vrt SRTM1.5d969aff1e1d4bcd92bd87c23b0c83aa.vrt
# make: Leaving directory '/home/quinn/.cache/elevation/SRTM1'
# make: Entering directory '/home/quinn/.cache/elevation/SRTM1'
# gdal_translate -q -co TILED=YES -co COMPRESS=DEFLATE -co ZLEVEL=9 -co PREDICTOR=2 -projwin -118.4907467773275 34.58806402907864 -118.3833471290849 34.49662891577207 SRTM1.5d969aff1e1d4bcd92bd87c23b0c83aa.vrt /home/quinn/pwfdf/data/dem.tif
# rm -f SRTM1.5d969aff1e1d4bcd92bd87c23b0c83aa.vrt
# make: Leaving directory '/home/quinn/.cache/elevation/SRTM1'
# x: -118.43707630192644, y: 34.54235771812747
